# %% [markdown]
# # Data Loading

# %%
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
tf.random.set_seed(10)
from tensorflow import keras
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
# Load the dataset
dataset, dataset_info = tfds.load(name='malaria', shuffle_files=True, with_info=True, as_supervised=True, split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'])

# %% [markdown]
# # Data Preprocessing

# %%
# Preprocessing function
def preprocess(image, label):
    image = tf.image.resize(image, [224, 224])  # Resize images to 224x224
    image = tf.cast(image, tf.float32)  # Convert images to float32
    return image, label

# Apply preprocessing
train_dataset, valid_dataset, test_dataset = dataset

train_dataset = train_dataset.map(preprocess)
valid_dataset = valid_dataset.map(preprocess)
test_dataset = test_dataset.map(preprocess)

# Normalization function
def normalise(image, label):
    return image / 255.0, label

# Apply normalization
train_dataset = train_dataset.map(normalise)
valid_dataset = valid_dataset.map(normalise)
test_dataset = test_dataset.map(normalise)

# Apply shuffling, batching, and prefetching
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(100).prefetch(tf.data.AUTOTUNE)
valid_dataset = valid_dataset.batch(100).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(100).prefetch(tf.data.AUTOTUNE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     return image, label
#       7 # Apply preprocessing
# ----> 8 train_dataset, valid_dataset, test_dataset = dataset
#      10 train_dataset = train_dataset.map(preprocess)
#      11 valid_dataset = valid_dataset.map(preprocess)
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
for i, (images, labels) in enumerate(train_dataset.take(1)):
    plt.figure(figsize=(10,6))
    for j in range(16):
        ax = plt.subplot(4, 4, j + 1)
        ax.imshow(images[j].numpy())
        label = labels[j].numpy()
        ax.set_title(dataset_info.features['label'].int2str(label))
        ax.axis('off')
plt.show()
# Out:
# 2024-08-29 12:13:03.577046: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # Sequential API

# %%
from keras.layers import Conv2D,MaxPool2D,Dense,InputLayer,Flatten,BatchNormalization
model = keras.Sequential([
    InputLayer(shape= (224,224,3)),
    Conv2D(filters=6, kernel_size=3, strides=1, padding='valid',activation='relu'),
    BatchNormalization(),
    MaxPool2D(strides=2),
    
    Conv2D(filters=18, kernel_size=3, strides=1, padding='valid',activation='relu'),
    BatchNormalization(),
    MaxPool2D(strides=2),

    Conv2D(filters=36, kernel_size=3, strides=1, padding='valid',activation='relu'),
    BatchNormalization(),
    MaxPool2D(strides=2),
    
    Conv2D(filters=48, kernel_size=3, strides=1, padding='valid',activation='relu'),
    BatchNormalization(),
    MaxPool2D(strides=2),
    
    Flatten(),
    
    Dense(1020,activation='relu'),
    Dense(680,activation='relu'),
    Dense(1,activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 222, 222, 6)    │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 222, 222, 6)    │            24 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 111, 111, 6)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 109, 109, 18)   │           990 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Model Compilation
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.metrics import Accuracy

model.compile(loss=BinaryCrossentropy(), optimizer=Adam(learning_rate=0.0005), metrics=['accuracy'])

# %%
history = model.fit(train_dataset,validation_data=valid_dataset,epochs=5)
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724926753.038434    1314 service.cc:146] XLA service 0x7fd3d401af70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724926753.038483    1314 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-08-29 10:19:13.097291: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-29 10:19:13.400246: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
# 2024-08-29 10:19:15.390757: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1971', 16 bytes spill stores, 16 bytes spill loads
#
# ...

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(test_dataset)
# Out:
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.9471 - loss: 0.1932
# [0.21619564294815063, 0.944847583770752]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
def parasiteOrNot(x):
    if x < 0.5:
        return "parasitized"
    else:
        return "uninfected"

# %%
import numpy as np
# Display images with their predicted labels
for i, (images, labels) in enumerate(train_dataset.take(1)):
    plt.figure(figsize=(10, 15))
    for j in range(16):
        ax = plt.subplot(4, 4, j + 1)
        ax.imshow(images[j].numpy())

        # Expand dimensions to match model input shape
        img_array = np.expand_dims(images[j].numpy(), axis=0)

        # Predict
        prediction = model.predict(img_array,verbose=0)
        label = labels[j].numpy()
        predicted_label = parasiteOrNot(prediction[0])

        # Display the label and prediction
        ax.set_title(f"True: {dataset_info.features['label'].int2str(label)}\nPred: {predicted_label}")
        ax.axis('off')

    plt.show()
# Out:
# 2024-08-29 10:30:55.089590: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # Functional API

# %% [markdown]
# ## Feature Extractor

# %%
from keras.layers import Input
from keras.models import Model

func_input = Input(shape=(224,224,3),name='Image')
x = Conv2D(filters=6, kernel_size=3, strides=1, padding='valid',activation='relu')(func_input)
x = BatchNormalization()(x)
x = MaxPool2D(strides=2)(x)
    
x = Conv2D(filters=18, kernel_size=3, strides=1, padding='valid',activation='relu')(x)
x = BatchNormalization()(x)
extractor = MaxPool2D(strides=2)(x)

feature_extractor = Model(func_input,extractor,name= "Feature extractor")
feature_extractor.summary()
# Out:
# Model: "Feature extractor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 222, 222, 6)    │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 222, 222, 6)    │            24 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 111, 111, 6)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## Fully CONNECTED lAYER

# %%
from keras.layers import Input
from keras.models import Model

func_input = Input(shape=(224,224,3),name='Image')
x = feature_extractor(func_input)
x = Flatten()(x)
    
x = Dense(100,activation='relu')(x)
x = Dense(10,activation='relu')(x)
func_output = Dense(1,activation='sigmoid')(x)

leNetModel = Model(func_input,func_output,name= "Lenet Model")
leNetModel.summary()
# Out:
# Model: "Lenet Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Feature extractor (Functional)  │ (None, 54, 54, 18)     │         1,254 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 52488)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 100)            │     5,248,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │         1,010 │
# ...

# %%
# Model Compilation
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.metrics import Accuracy

leNetModel.compile(loss=BinaryCrossentropy(), optimizer=Adam(learning_rate=0.0005), metrics=['accuracy'])

# %%
leNethistory = model.fit(train_dataset,validation_data=valid_dataset,epochs=3)
# Out:
# Epoch 1/3
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 198s 287ms/step - accuracy: 0.9834 - loss: 0.0508 - val_accuracy: 0.9459 - val_loss: 0.2589
# Epoch 2/3
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 198s 287ms/step - accuracy: 0.9895 - loss: 0.0302 - val_accuracy: 0.9445 - val_loss: 0.2735
# Epoch 3/3
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 198s 287ms/step - accuracy: 0.9896 - loss: 0.0328 - val_accuracy: 0.9434 - val_loss: 0.2963

# %% [markdown]
# # Model Subclassing

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer, Conv2D, BatchNormalization, MaxPooling2D, Input,Flatten,Dense

class FeatureExtractor(Layer):
    def __init__(self, filters, kernel_size, strides, padding, activation, pooling):
        super(FeatureExtractor, self).__init__()
        self.conv_1 = Conv2D(filters, kernel_size, strides=strides, padding=padding, activation=activation)
        self.batch_1 = BatchNormalization()
        self.pool_1 = MaxPooling2D(pool_size=pooling, strides=2*strides)
        
        self.conv_2 = Conv2D(filters*2, kernel_size, strides=strides, padding=padding, activation=activation)
        self.batch_2 = BatchNormalization()
        self.pool_2 = MaxPooling2D(pool_size=pooling, strides=2*strides)
        
    def call(self, x):
        x = self.conv_1(x)
        x = self.batch_1(x)
        x = self.pool_1(x)
        
        x = self.conv_2(x)
        x = self.batch_2(x)
        x = self.pool_2(x)

        return x

# %%
from tensorflow.keras.models import Model

class LeNetModel(Model):
    def __init__(self, filters, kernel_size, strides, padding, activation, pooling):
        super(LeNetModel, self).__init__()
        self.featureExtractor = FeatureExtractor(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding, activation=activation, pooling=pooling)
        
        self.flatten = Flatten()
        
        # Add additional layers
        self.dense_1 = Dense(100, activation='relu')
        self.batch_1 = BatchNormalization()
        self.dense_2 = Dense(60, activation='relu')
        self.batch_2 = BatchNormalization()
        self.dense_3 = Dense(10, activation='relu')
        self.batch_3 = BatchNormalization()
        self.output_layer = Dense(1, activation='sigmoid')

    def call(self, x):
        x = self.featureExtractor(x)
        
        x = self.flatten(x)
        x = self.dense_1(x)
        x = self.batch_1(x)
        x = self.dense_2(x)
        x = self.batch_2(x)
        x = self.dense_3(x)
        x = self.batch_3(x)
        
        func_output = self.output_layer(x)
        return func_output

# Define input tensor
input_tensor = Input(shape=(224, 224, 3), name='Image')

# Instantiate the custom LeNetModel
feature_extractor = LeNetModel(filters=6, kernel_size=3, strides=1, padding="valid", activation="relu", pooling=2)

# Apply the custom model
output_tensor = feature_extractor(input_tensor)

# Create the model
lenetSubClassModel = tf.keras.Model(inputs=input_tensor, outputs=output_tensor)
lenetSubClassModel.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ le_net_model_3 (LeNetModel)     │ (None, 1)              │     3,507,561 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,507,561 (13.38 MB)
#  Trainable params: 3,507,185 (13.38 MB)
#  Non-trainable params: 376 (1.47 KB)

# %%
lenetSubClassModel.compile(loss=BinaryCrossentropy(), optimizer=Adam(learning_rate=0.0005), metrics=['accuracy'])

# %%
lenetSubClassModelHistory = lenetSubClassModel.fit(train_dataset,validation_data=valid_dataset,epochs=3)
# Out:
# Epoch 1/3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724933610.742583    3002 service.cc:146] XLA service 0x7f4d4c015ff0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724933610.742619    3002 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2024-08-29 12:13:30.807506: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-29 12:13:31.129835: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8906
#   1/221 ━━━━━━━━━━━━━━━━━━━━ 43:28 12s/step - accuracy: 0.4400 - loss: 1.0339
# I0000 00:00:1724933619.787682    3002 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# ...

# %%
plt.plot(lenetSubClassModelHistory.history['loss'])
plt.plot(lenetSubClassModelHistory.history['val_loss'])
