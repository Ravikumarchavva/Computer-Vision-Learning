# %%
import tensorflow as tf
tf.random.set_seed(10)
import tensorflow_datasets as tfds
dataset, dataset_info = tfds.load(name='malaria', shuffle_files=True, with_info=True, as_supervised=True, split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'])

# %%
# Preprocessing function
def preprocess(image, label):
    image = tf.image.resize(image, [224, 224])  # Resize images to 224x224
    image = tf.cast(image, tf.float32)  # Convert images to float32
    return image, label

# Apply preprocessing
train_dataset, valid_dataset, test_dataset = dataset

train_dataset = train_dataset.map(preprocess)
valid_dataset = valid_dataset.map(preprocess)
test_dataset = test_dataset.map(preprocess)

# Normalization function
def normalise(image, label):
    return image / 255, label

# Apply normalization
train_dataset = train_dataset.map(normalise)
valid_dataset = valid_dataset.map(normalise)
test_dataset = test_dataset.map(normalise)

# Apply shuffling, batching, and prefetching
train_dataset = train_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
valid_dataset = valid_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
import matplotlib.pyplot as plt
for i, (images, labels) in enumerate(train_dataset.take(1)):
    plt.figure(figsize=(10,6))
    for j in range(16):
        ax = plt.subplot(4, 4, j + 1)
        ax.imshow(images[j].numpy())
        label = labels[j].numpy()
        ax.set_title(dataset_info.features['label'].int2str(label))
        ax.axis('off')
plt.show()
# Out:
# 2024-09-02 04:45:45.064568: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def visualaize(image,agImg,k=2):
    for i in range(k):
        plt.subplot(1,2,1)
        plt.imshow(image[i])
        plt.subplot(1,2,2)
        plt.imshow(agImg[i])
        plt.show()

# %%
image,label=next(iter(train_dataset))

# %%
agImage,label = tf.image.flip_left_right(image),label
visualaize(image,agImage)

# %%
agFlip = tf.image.random_flip_up_down(image)
visualaize(image,agFlip)

# %%
agSat = tf.image.adjust_saturation(image,saturation_factor=2.0)
visualaize(image,agSat)

# %%
agBri = tf.image.adjust_brightness(image,delta=.1)
visualaize(image,agBri)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.1..1.0307033].

# %%
agCc = tf.image.central_crop(image,central_fraction=.9)
visualaize(image,agCc)

# %% [markdown]
# # Augumentation

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Dataset loading and preprocessing (as in your code)
dataset, dataset_info = tfds.load(name='malaria', shuffle_files=True, with_info=True, as_supervised=True, split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'])

def augument(image, label):
    image = tf.image.rot90(image)
    image = tf.image.adjust_saturation(image, saturation_factor=2.0)
    image = tf.image.central_crop(image, central_fraction=0.9)
    image = tf.image.adjust_brightness(image, delta=0.2)
    return image, label

def preprocess(image, label):
    image = tf.image.resize(image, [224, 224])  # Resize images to 224x224
    image = tf.cast(image, tf.float32)  # Convert images to float32
    return image / 255, label

train_dataset, valid_dataset, test_dataset = dataset

train_dataset = train_dataset.map(augument).map(preprocess)
valid_dataset = valid_dataset.map(augument).map(preprocess)
test_dataset = test_dataset.map(preprocess)

train_dataset = train_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
valid_dataset = valid_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the model with debug prints for output shapes
model = models.Sequential()

model.add(layers.InputLayer(shape=(224, 224, 3)))

model.add(layers.Conv2D(filters=6, kernel_size=3, strides=1, padding='valid', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(strides=2))
print(model.output_shape)  # (None, 111, 111, 6)

model.add(layers.Conv2D(filters=18, kernel_size=3, strides=1, padding='valid', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(strides=2))
print(model.output_shape)  # (None, 54, 54, 18)

model.add(layers.Conv2D(filters=36, kernel_size=3, strides=1, padding='valid', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(strides=2))
print(model.output_shape)  # (None, 26, 26, 36)

model.add(layers.Conv2D(filters=48, kernel_size=3, strides=1, padding='valid', activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPool2D(strides=2))
print(model.output_shape)  # (None, 12, 12, 48)

model.add(layers.Flatten())
print(model.output_shape)  # (None, 6912)

# Adjust the Dense layer to match the Flatten output
model.add(layers.Dense(602, activation='relu'))  # Adjust to match the output of the Flatten layer
model.add(layers.Dense(680, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()

# Model Compilation
model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005), metrics=['accuracy'])

# Assuming train_dataset and valid_dataset are defined as shown earlier
history = model.fit(train_dataset, validation_data=valid_dataset, epochs=20)
# Out:
# (None, 111, 111, 6)
# (None, 54, 54, 18)
# (None, 26, 26, 36)
# (None, 12, 12, 48)
# (None, 6912)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)              │ (None, 222, 222, 6)    │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 222, 222, 6)    │            24 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 111, 111, 6)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 109, 109, 18)   │           990 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 109, 109, 18)   │            72 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 54, 54, 18)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 52, 52, 36)     │         5,868 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 52, 52, 36)     │           144 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 26, 26, 36)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 24, 24, 48)     │        15,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 24, 24, 48)     │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 12, 12, 48)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 6912)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 602)            │     4,161,626 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 680)            │       410,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │           681 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,595,405 (17.53 MB)
#  Trainable params: 4,595,189 (17.53 MB)
#  Non-trainable params: 216 (864.00 B)
# Epoch 1/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 38s 47ms/step - accuracy: 0.8254 - loss: 0.4568 - val_accuracy: 0.9184 - val_loss: 0.2256
# Epoch 2/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 31s 45ms/step - accuracy: 0.9470 - loss: 0.1524 - val_accuracy: 0.9321 - val_loss: 0.2034
# Epoch 3/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.9608 - loss: 0.1148 - val_accuracy: 0.9412 - val_loss: 0.1902
# Epoch 4/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 38ms/step - accuracy: 0.9683 - loss: 0.0902 - val_accuracy: 0.9412 - val_loss: 0.1792
# Epoch 5/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.9748 - loss: 0.0743 - val_accuracy: 0.9361 - val_loss: 0.2216
# Epoch 6/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 29s 41ms/step - accuracy: 0.9797 - loss: 0.0575 - val_accuracy: 0.9271 - val_loss: 0.2958
# Epoch 7/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 31s 45ms/step - accuracy: 0.9822 - loss: 0.0484 - val_accuracy: 0.9329 - val_loss: 0.2446
# Epoch 8/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 30s 43ms/step - accuracy: 0.9851 - loss: 0.0449 - val_accuracy: 0.9267 - val_loss: 0.3453
# Epoch 9/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 29s 42ms/step - accuracy: 0.9903 - loss: 0.0326 - val_accuracy: 0.9470 - val_loss: 0.2899
# Epoch 10/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 27s 39ms/step - accuracy: 0.9915 - loss: 0.0237 - val_accuracy: 0.9361 - val_loss: 0.3461
# Epoch 11/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 28s 40ms/step - accuracy: 0.9899 - loss: 0.0285 - val_accuracy: 0.9409 - val_loss: 0.3125
# Epoch 12/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 38ms/step - accuracy: 0.9918 - loss: 0.0217 - val_accuracy: 0.9372 - val_loss: 0.4247
# Epoch 13/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.9924 - loss: 0.0230 - val_accuracy: 0.9180 - val_loss: 0.4517
# Epoch 14/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 3038s 4s/step - accuracy: 0.9895 - loss: 0.0298 - val_accuracy: 0.9438 - val_loss: 0.3797
# Epoch 15/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 26s 38ms/step - accuracy: 0.9960 - loss: 0.0133 - val_accuracy: 0.9419 - val_loss: 0.3587
# Epoch 16/20
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 25s 36ms/step - accuracy: 0.9967 - loss: 0.0104 - val_accuracy: 0.9376 - val_loss: 0.4129
# Epoch 17/20
# 561/689 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9981 - loss: 0.0069

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
